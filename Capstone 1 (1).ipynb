# %% [markdown]
# # NoteBook Project
# ###### ###### Create a new repository on your Github account and name it Coursera_Capstone. If you don't have a Github account yet, please create one and follow the instructions here: https://services.github.com/on-demand/intro-to-github/create-github-account.
# ###### Now, start a Jupyter Notebook using any platform that you are comfortable with and do the following:
# ###### To write some markdown to explain that this notebook will be mainly used for the capstone project.
# ###### To import the pandas library as pd.
# ######  To import the Numpy library as np.
# ###### To print the following the statement: Hello Capstone Project C ourse!
# ###### To push the Notebook to your Github repository and submit a link to the notebook on your Github repository.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course
